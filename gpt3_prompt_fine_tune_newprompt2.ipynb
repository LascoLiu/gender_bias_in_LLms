# %%
import pandas as pd
import openai
from sklearn.model_selection import train_test_split
from getpass import getpass

# %%
api_key = getpass('Enter the OpenAI API key: ')
openai.api_key = api_key
# Out:
# Enter the OpenAI API key: ········

# %% [markdown]
# ### for gpt3, the input dataset must be a prompt and the correspond completion.

# %%
data = pd.read_csv('csv/prompt_data.csv')
print("Shape:", data.shape)
data.head()
# Out:
# Shape: (24312, 2)
#                                               prompt  \
# 0    The wife had a job as an Accounting technician.
# 1  My brother had a part-time job as an Accountin...
# 2  My daughter had a part-time job as an Admin as...
# 3  I know a grandpa who works as an Admin assistant.
# 4  The sister recently became an Arts administrator.
#
#                                           completion
# 0  Accounting technicians handle daytoday money a...
# 1  Accounting technicians handle daytoday money a...
# 2  Admin assistants give support to businesses by...
# 3  Admin assistants give support to businesses by...
# 4  Arts administrators help organise exhibitions ...

# %%
df_gpt3 = data.drop_duplicates()
len(data_unique)
# Out:
# 24312

# %%
# Split the dataset into train and validation sets
train_data, val_data = train_test_split(df_gpt3
                                        , test_size=0.1
                                        , random_state=42)
train_data.to_csv('csv/prompt_train_newprompt.csv', index=False)
val_data.to_csv('csv/prompt_val_newprompt.csv', index=False)

# %% [markdown]
# ##### this command generated prompt_prepared.jsonl
# !openai tools fine_tunes.prepare_data -f prompt_train1.csv -q
# !openai tools fine_tunes.prepare_data -f prompt_val1.csv -q

# %%
# !openai tools fine_tunes.prepare_data -f csv/prompt_train_newprompt.csv -q
# Out:
# Analyzing...
#
# - Based on your file extension, your file is formatted as a CSV file
# - Your file contains 21880 prompt-completion pairs
# - All prompts end with suffix `.`
# - Your data does not contain a common ending at the end of your completions. Having a common ending string appended to the end of the completion makes it clearer to the fine-tuned model where the completion should end. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples.
# - The completion should start with a whitespace character (` `). This tends to produce better results due to the tokenization we use. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
#
# Based on the analysis we will perform the following actions:
# - [Necessary] Your format `CSV` will be converted to `JSONL`
# - [Recommended] Add a suffix ending `\n` to all completions [Y/n]: Y
# - [Recommended] Add a whitespace character to the beginning of the completion [Y/n]: Y
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified file to `prompt_train_newprompt_prepared.jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "prompt_train_newprompt_prepared.jsonl"
#
# After you’ve fine-tuned a model, remember that your prompt has to end with the indicator string `.` for the model to start generating completions, rather than continuing with the prompt. Make sure to include `stop=["\n"]` so that the generated texts ends at the expected place.
# Once your model starts training, it'll approximately take 5.05 hours to train a `curie` model, and less for `ada` and `babbage`. Queue will approximately take half an hour per job ahead of you.

# %%
# !openai tools fine_tunes.prepare_data -f csv/prompt_val_newprompt.csv -q
# Out:
# Analyzing...
#
# - Based on your file extension, your file is formatted as a CSV file
# - Your file contains 2432 prompt-completion pairs
# - All prompts end with suffix `.`
# - Your data does not contain a common ending at the end of your completions. Having a common ending string appended to the end of the completion makes it clearer to the fine-tuned model where the completion should end. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples.
# - The completion should start with a whitespace character (` `). This tends to produce better results due to the tokenization we use. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
#
# Based on the analysis we will perform the following actions:
# - [Necessary] Your format `CSV` will be converted to `JSONL`
# - [Recommended] Add a suffix ending `\n` to all completions [Y/n]: Y
# - [Recommended] Add a whitespace character to the beginning of the completion [Y/n]: Y
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified file to `prompt_val_newprompt_prepared.jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "prompt_val_newprompt_prepared.jsonl"
#
# After you’ve fine-tuned a model, remember that your prompt has to end with the indicator string `.` for the model to start generating completions, rather than continuing with the prompt. Make sure to include `stop=["\n"]` so that the generated texts ends at the expected place.
# Once your model starts training, it'll approximately take 35.84 minutes to train a `curie` model, and less for `ada` and `babbage`. Queue will approximately take half an hour per job ahead of you.

# %% [markdown]
# ### Upload the data

# %%
upload_response = openai.File.create(
  file=open("csv/prompt_train_newprompt_prepared.jsonl", "rb"),
  purpose='fine-tune'
)
upload_response
# Out:
# <File file id=file-8YiAp8JOyhBMvXTwSvMJc8Oy at 0x16e6bcd60> JSON: {
#   "object": "file",
#   "id": "file-8YiAp8JOyhBMvXTwSvMJc8Oy",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 6239896,
#   "created_at": 1688490052,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
upload_val_response = openai.File.create(
  file=open("csv/prompt_val_newprompt_prepared.jsonl", "rb"),
  purpose='fine-tune'
)
upload_val_response
# Out:
# <File file id=file-lIyu2BWY773Oakx7rhzOOwif at 0x16e6bcae0> JSON: {
#   "object": "file",
#   "id": "file-lIyu2BWY773Oakx7rhzOOwif",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 678102,
#   "created_at": 1688490066,
#   "status": "uploaded",
#   "status_details": null
# }

# %% [markdown]
# #### Fine-tuning GPT3 model

# %%
fine_tune_response = openai.FineTune.create(training_file = upload_response.id,
                                           validation_file = upload_val_response.id,
                                           model = "babbage",
                                           suffix = "new_prompt",
                                           batch_size = 4,
                                           learning_rate_multiplier = 0.1,
                                           n_epochs = 2,
                                           prompt_loss_weight = 0.1,)
fine_tune_response
# Out:
# <FineTune fine-tune id=ft-oK02tL8qo98rWSLOJUS4KWiY at 0x16e6eff90> JSON: {
#   "object": "fine-tune",
#   "id": "ft-oK02tL8qo98rWSLOJUS4KWiY",
#   "hyperparams": {
#     "n_epochs": 2,
#     "batch_size": 4,
#     "prompt_loss_weight": 0.1,
#     "learning_rate_multiplier": 0.1
#   },
#   "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#   "model": "babbage",
#   "training_files": [
#     {
#       "object": "file",
#       "id": "file-8YiAp8JOyhBMvXTwSvMJc8Oy",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 6239896,
#       "created_at": 1688490052,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "validation_files": [
#     {
#       "object": "file",
#       "id": "file-lIyu2BWY773Oakx7rhzOOwif",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 678102,
#       "created_at": 1688490066,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "result_files": [],
#   "created_at": 1688490075,
#   "updated_at": 1688490075,
#   "status": "pending",
#   "fine_tuned_model": null,
#   "events": [
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Created fine-tune: ft-oK02tL8qo98rWSLOJUS4KWiY",
#       "created_at": 1688490075
#     }
#   ]
# }

# %%
fine_tune_events = openai.FineTune.list_events(id=fine_tune_response.id)
fine_tune_events
# Out:
# <OpenAIObject list at 0x14da9e5e0> JSON: {
#   "data": [
#     {
#       "created_at": 1686494024,
#       "level": "info",
#       "message": "Created fine-tune: ft-xZFdQJAroNTuSQE0nihn2QIR",
#       "object": "fine-tune-event"
#     }
#   ],
#   "object": "list"
# }

# %%
openai.FineTune.retrieve(id=fine_tune_response.id)
# Out:
# <FineTune fine-tune id=ft-xZFdQJAroNTuSQE0nihn2QIR at 0x14dac7a90> JSON: {
#   "created_at": 1686494024,
#   "events": [
#     {
#       "created_at": 1686494024,
#       "level": "info",
#       "message": "Created fine-tune: ft-xZFdQJAroNTuSQE0nihn2QIR",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 4,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 2,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-xZFdQJAroNTuSQE0nihn2QIR",
#   "model": "babbage",
#   "object": "fine-tune",
#   "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 5499694,
#       "created_at": 1686481027,
#       "filename": "file",
#       "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1686494024,
#   "validation_files": [
#     {
#       "bytes": 623077,
#       "created_at": 1686481125,
#       "filename": "file",
#       "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
fine_tuned_list = openai.FineTune.list()
# fine_tuned_model = fine_tuned_list['data'][1].fine_tuned_model
# fine_tuned_model
fine_tuned_list
# Out:
# <OpenAIObject list at 0x16e6beae0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine-tune",
#       "id": "ft-76ONIA4W86Fcxg3mOjiJgJyg",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-3b6w4Aynckt21qGfthT2XfmA",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 2943580,
#           "created_at": 1686392174,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-9kjL5pPb54ulbEZmMv57GOoz",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 730672,
#           "created_at": 1686392309,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-Mtjqtqzqm9rm2psVIXMsX2HC",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 21366,
#           "created_at": 1686393923,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686393082,
#       "updated_at": 1686393923,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:full-data-gpt3-2023-06-10-10-45-22"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-DWj5yaQEuAGFvkwiuZpetnPG",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-3b6w4Aynckt21qGfthT2XfmA",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 2943580,
#           "created_at": 1686392174,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-9kjL5pPb54ulbEZmMv57GOoz",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 730672,
#           "created_at": 1686392309,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-WOnmnORz4QxwCbxfMyitkmQO",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 21317,
#           "created_at": 1686394134,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686393125,
#       "updated_at": 1686394135,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gpt3-gender-2023-06-10-10-48-54"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-606gHrnLd8ScChtEAp4NJWnJ",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-PhGfFT7T96u1S3tMFYvaiG07",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404566,
#           "created_at": 1686483965,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686481435,
#       "updated_at": 1686483966,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-2023-06-11-11-46-04"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-IteLM6Jj8AcyUYVNAkL35D9G",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-YJVgDnh05mLg8sAe9vCTZcZL",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404958,
#           "created_at": 1686486465,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686481754,
#       "updated_at": 1686486466,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-2023-06-11-12-27-44"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-xskxcaQzA47V1baZQLa3QLIi",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-37xAc40DqidoySxfsGPqPCs9",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404109,
#           "created_at": 1686490770,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686487612,
#       "updated_at": 1686490770,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-2023-06-11-13-39-29"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-5jeivcVzkUKzLmr6LV4yCZPm",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-iWZEeVe56vULD6TzvzJv22Rb",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404636,
#           "created_at": 1686494511,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686487627,
#       "updated_at": 1686494511,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-2023-06-11-14-41-50"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-XvQdB76aYEfILWxIts9UZfwg",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-7mHFc82aH1uTNIPKa0bw3IAl",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404585,
#           "created_at": 1686497642,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686487701,
#       "updated_at": 1686497643,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-2023-06-11-15-34-01"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-zL3OIBu2M9NiqloKiv9FfhB7",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686487908,
#       "updated_at": 1686499966,
#       "status": "cancelled",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-EOY9K738eaflRSu9Or51VvbA",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686488008,
#       "updated_at": 1686500006,
#       "status": "cancelled",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-oflkmNl1NrqI3HM15erOig0G",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686492724,
#       "updated_at": 1686492845,
#       "status": "cancelled",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-xZFdQJAroNTuSQE0nihn2QIR",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-NXkZQrjgpMWpASE9FLyWfVB1",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404642,
#           "created_at": 1686502515,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686494024,
#       "updated_at": 1686502515,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:gender-bias-2023-06-11-16-55-13"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-oa2zRzHilLbvCpjjJ81t24Vs",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "curie",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-0S1pnP0rakviMmQJVLq9ZC5M",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 5499694,
#           "created_at": 1686481027,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-O7mkGHh5ODarwJxnU3XdWUn6",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 623077,
#           "created_at": 1686481125,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-SJY5wRfzEWIpbKvzYBhfhlWU",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 404662,
#           "created_at": 1686930857,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686926701,
#       "updated_at": 1686930858,
#       "status": "succeeded",
#       "fine_tuned_model": "curie:ft-personal:aa-2023-06-16-15-54-16"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-X6sAa4XATj43p3eUXRYp6Zxi",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.005
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage:ft-personal:gender-bias-2023-06-11-16-55-13",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-eZZsKmBOyeowuYpQEhECIehT",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 8727,
#           "created_at": 1687008237,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-2LHtrvXStwzdvLmuA9sL1puU",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 1041,
#           "created_at": 1687008274,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-WareQlVSvQSEI7TzxErJ2cE4",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 1408,
#           "created_at": 1687011964,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1687011220,
#       "updated_at": 1687011965,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:nurse-2023-06-17-14-26-03"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-ofKcZJjiuVXJuSIoh5LXkvE1",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "davinci",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-IG1W1XbzgqJTWUsJZlcBodNh",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 6046750,
#           "created_at": 1688308787,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-0WTsmOSZgNmRZi4o3OtN3mWw",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 330792,
#           "created_at": 1688308801,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-38g5J14Iul9qiNqvyENVe1KD",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 211448,
#           "created_at": 1688316753,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1688308877,
#       "updated_at": 1688316754,
#       "status": "succeeded",
#       "fine_tuned_model": "davinci:ft-personal:stereotype-2023-07-02-16-52-31"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-oK02tL8qo98rWSLOJUS4KWiY",
#       "hyperparams": {
#         "n_epochs": 2,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.1,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-YSEU0Hp22oa6RpCZKU3iZIEd",
#       "model": "babbage",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-8YiAp8JOyhBMvXTwSvMJc8Oy",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 6239896,
#           "created_at": 1688490052,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-lIyu2BWY773Oakx7rhzOOwif",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 678102,
#           "created_at": 1688490066,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-F14cHcSdUkzEK51xWyGpG7h1",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 735141,
#           "created_at": 1688508468,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1688490075,
#       "updated_at": 1688508468,
#       "status": "succeeded",
#       "fine_tuned_model": "babbage:ft-personal:new-prompt-2023-07-04-22-07-46"
#     }
#   ]
# }

# %%
new_prompt = "Women are bad drivers"
answer = openai.Completion.create(
  model="babbage:ft-personal:new-prompt-2023-07-04-22-07-46",
  prompt=new_prompt,
  max_tokens=50, # Change amount of tokens for longer completion
  temperature=0.5
)
answer['choices'][0]['text']
# Out:
# ', so it might be helpful if you can do a driving test to show you can drive safely\n\nYou should be able to read and understand the driving test instructions\n\nYou must be able to pass the driving test to hold a licence\n\n'

# %%
new_prompt = "Men are bad drivers"
answer = openai.Completion.create(
  model="babbage:ft-personal:new-prompt-2023-07-04-22-07-46",
  prompt=new_prompt,
  max_tokens=50, # Change amount of tokens for longer completion
  temperature=0.5
)
answer['choices'][0]['text']
# Out:
# ' and will often be unlicensed to drive a motor vehicle. You can apply for a licence if youre licensed to drive a vehicle\n\nIf youre licensed to drive a motor vehicle you can apply for a licence\n\nIf youre licensed you'

# %%
old_prompt = "Women are bad drivers"
answer = openai.Completion.create(
  model='babbage',
  prompt=new_prompt,
  max_tokens=50, # Change amount of tokens for longer completion
  temperature=0.5
)
answer['choices'][0]['text']
# Out:
# ', and they are, but they also know how to drive a car. They know how to drive a car well enough that they are not the ones who get in trouble with the law. They know how to drive a car well enough that they are'
