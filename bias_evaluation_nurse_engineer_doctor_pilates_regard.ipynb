# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast

# %%
df_reg = pd.read_csv('csv/nurse_engineer_regard_average_score.csv')
df_reg_comparison = pd.read_csv('csv/nurse_engineer_regard_average_score_comparison.csv')
df_reg_d = pd.read_csv('csv/nurse_doctor_regard_average_score.csv')
df_reg_d_comparison = pd.read_csv('csv/nurse_doctor_regard_average_score_comparison.csv')
df_reg_p = pd.read_csv('csv/pilates_engineer_regard_average_score.csv')
df_reg_p_comparison = pd.read_csv('csv/pilates_engineer_regard_average_score_comparison.csv')

# %%
m_nurse_score1 = df_reg['ft_m_nurse_score']
f_engineer_score1 = df_reg['ft_f_engineer_score']
pt_m_nurse_score1 = df_reg['pt_m_nurse_score']
pt_f_engineer_score1 = df_reg['pt_f_engineer_score']

f_nurse_score1_com = df_reg_comparison['ft_f_nurse_score']
m_engineer_score1_com = df_reg_comparison['ft_m_engineer_score']
pt_f_nurse_score1_com = df_reg_comparison['pt_f_nurse_score']
pt_m_engineer_score1_com = df_reg_comparison['pt_m_engineer_score']

f_doctor_score1 = df_reg_d['ft_f_doctor_score']
pt_f_doctor_score1 = df_reg_d['pt_f_doctor_score']
m_doctor_score1_com = df_reg_d_comparison['ft_m_doctor_score']
pt_m_doctor_score1_com = df_reg_d_comparison['pt_m_doctor_score']

m_pilates_score1 = df_reg_p['ft_m_pilates_score']
pt_m_pilates_score1 = df_reg_p['pt_m_pilates_score']
f_pilates_score1_com =df_reg_p_comparison['ft_f_pilates_score']
pt_f_pilates_score1_com = df_reg_p_comparison['pt_f_pilates_score']

# %% [markdown]
# ### Visualization

# %%
# fine tuned
m_nurse_scores = ast.literal_eval(m_nurse_score1[0])
f_nurse_scores = ast.literal_eval(f_nurse_score1_com[0])
f_engineer_scores = ast.literal_eval(f_engineer_score1[0])
m_engineer_scores = ast.literal_eval(m_engineer_score1_com[0])


print(f_nurse_scores)
negative_scores_m_nurse = m_nurse_scores['negative']
neutral_scores_m_nurse = m_nurse_scores['neutral']
positive_scores_m_nurse = m_nurse_scores['positive']
other_scores_m_nurse = m_nurse_scores['other']

negative_scores_f_nurse_com = f_nurse_scores['negative']
neutral_scores_f_nurse_com = f_nurse_scores['neutral']
positive_scores_f_nurse_com = f_nurse_scores['positive']
other_scores_f_nurse_com = f_nurse_scores['other']


negative_scores_f_engineer = f_engineer_scores['negative']
neutral_scores_f_engineer = f_engineer_scores['neutral']
positive_scores_f_engineer = f_engineer_scores['positive']
other_scores_f_engineer = f_engineer_scores['other']

negative_scores_m_engineer_com = m_engineer_scores['negative']
neutral_scores_m_engineer_com = m_engineer_scores['neutral']
positive_scores_m_engineer_com = m_engineer_scores['positive']
other_scores_m_engineer_com = m_engineer_scores['other']

# baseline
pt_m_nurse_scores = ast.literal_eval(pt_m_nurse_score1[0])
pt_f_nurse_scores = ast.literal_eval(pt_f_nurse_score1_com[0])
pt_f_engineer_scores = ast.literal_eval(pt_f_engineer_score1[0])
pt_m_engineer_scores = ast.literal_eval(pt_m_engineer_score1_com[0])
print(m_nurse_scores)
negative_scores_m_nurse_pt = pt_m_nurse_scores['negative']
neutral_scores_m_nurse_pt = pt_m_nurse_scores['neutral']
positive_scores_m_nurse_pt = pt_m_nurse_scores['positive']
other_scores_m_nurse_pt = pt_m_nurse_scores['other']

negative_scores_f_nurse_pt_com = pt_f_nurse_scores['negative']
neutral_scores_f_nurse_pt_com = pt_f_nurse_scores['neutral']
positive_scores_f_nurse_pt_com = pt_f_nurse_scores['positive']
other_scores_f_nurse_pt_com = pt_f_nurse_scores['other']

negative_scores_f_engineer_pt = pt_f_engineer_scores['negative']
neutral_scores_f_engineer_pt = pt_f_engineer_scores['neutral']
positive_scores_f_engineer_pt = pt_f_engineer_scores['positive']
other_scores_f_engineer_pt = pt_f_engineer_scores['other']

negative_scores_m_engineer_pt_com = pt_m_engineer_scores['negative']
neutral_scores_m_engineer_pt_com = pt_m_engineer_scores['neutral']
positive_scores_m_engineer_pt_com = pt_m_engineer_scores['positive']
other_scores_m_engineer_pt_com = pt_m_engineer_scores['other']

# fine tuned doctor
f_doctor_scores = ast.literal_eval(f_doctor_score1[0])
m_doctor_scores = ast.literal_eval(m_doctor_score1_com[0])

negative_scores_f_doctor = f_doctor_scores['negative']
neutral_scores_f_doctor = f_doctor_scores['neutral']
positive_scores_f_doctor = f_doctor_scores['positive']
other_scores_f_doctor = f_doctor_scores['other']

negative_scores_m_doctor_com = m_doctor_scores['negative']
neutral_scores_m_doctor_com = m_doctor_scores['neutral']
positive_scores_m_doctor_com = m_doctor_scores['positive']
other_scores_m_doctor_com = m_doctor_scores['other']

# baseline doctor
pt_f_doctor_scores = ast.literal_eval(pt_f_doctor_score1[0])
pt_m_doctor_scores = ast.literal_eval(pt_m_doctor_score1_com[0])

negative_scores_f_doctor_pt = pt_f_doctor_scores['negative']
neutral_scores_f_doctor_pt = pt_f_doctor_scores['neutral']
positive_scores_f_doctor_pt = pt_f_doctor_scores['positive']
other_scores_f_doctor_pt = pt_f_doctor_scores['other']

negative_scores_m_doctor_pt_com = pt_m_doctor_scores['negative']
neutral_scores_m_doctor_pt_com = pt_m_doctor_scores['neutral']
positive_scores_m_doctor_pt_com = pt_m_doctor_scores['positive']
other_scores_m_doctor_pt_com = pt_m_doctor_scores['other']

# fine tuned pilates teacher
m_pilates_scores = ast.literal_eval(m_pilates_score1[0])
f_pilates_scores = ast.literal_eval(f_pilates_score1_com[0])

negative_scores_m_pilates = m_pilates_scores['negative']
neutral_scores_m_pilates = m_pilates_scores['neutral']
positive_scores_m_pilates = m_pilates_scores['positive']
other_scores_m_pilates = m_pilates_scores['other']

negative_scores_f_pilates_com = f_pilates_scores['negative']
neutral_scores_f_pilates_com = f_pilates_scores['neutral']
positive_scores_f_pilates_com = f_pilates_scores['positive']
other_scores_f_pilates_com = f_pilates_scores['other']

# baseline pilates teacher
pt_m_pilates_scores = ast.literal_eval(pt_m_pilates_score1[0])
pt_f_pilates_scores = ast.literal_eval(pt_f_pilates_score1_com[0])

negative_scores_m_pilates_pt = pt_m_pilates_scores['negative']
neutral_scores_m_pilates_pt = pt_m_pilates_scores['neutral']
positive_scores_m_pilates_pt = pt_m_pilates_scores['positive']
other_scores_m_pilates_pt = pt_m_pilates_scores['other']

negative_scores_f_pilates_pt_com = pt_f_pilates_scores['negative']
neutral_scores_f_pilates_pt_com = pt_f_pilates_scores['neutral']
positive_scores_f_pilates_pt_com = pt_f_pilates_scores['positive']
other_scores_f_pilates_pt_com = pt_f_pilates_scores['other']
# Out:
# {'positive': 0.8022633221000433, 'other': 0.08571060289395974, 'neutral': 0.10104986007791013, 'negative': 0.010976216112612746}
# {'positive': 0.8448304949328304, 'neutral': 0.10127869935240597, 'other': 0.046860080352053045, 'negative': 0.0070307201240211725}

# %%
m_nurse_scores = [positive_scores_m_nurse, negative_scores_m_nurse, neutral_scores_m_nurse, other_scores_m_nurse]
f_nurse_scores = [positive_scores_f_nurse_com, negative_scores_f_nurse_com, neutral_scores_f_nurse_com, other_scores_f_nurse_com]
print(positive_scores_f_nurse_com)
f_engineer_scores = [positive_scores_f_engineer, negative_scores_f_engineer, neutral_scores_f_engineer, other_scores_f_engineer]
m_engineer_scores = [positive_scores_m_engineer_com, negative_scores_m_engineer_com, neutral_scores_m_engineer_com, other_scores_m_engineer_com]

pt_m_nurse_scores = [positive_scores_m_nurse_pt, negative_scores_m_nurse_pt, neutral_scores_m_nurse_pt, other_scores_m_nurse_pt]
pt_f_nurse_scores = [positive_scores_f_nurse_pt_com, negative_scores_f_nurse_pt_com, neutral_scores_f_nurse_pt_com, other_scores_f_nurse_pt_com]

pt_f_engineer_scores = [positive_scores_f_engineer_pt, negative_scores_f_engineer_pt, neutral_scores_f_engineer_pt, other_scores_f_engineer_pt]
pt_m_engineer_scores = [positive_scores_m_engineer_pt_com, negative_scores_m_engineer_pt_com, neutral_scores_m_engineer_pt_com, other_scores_m_engineer_pt_com]

f_doctor_scores = [positive_scores_f_doctor, negative_scores_f_doctor, neutral_scores_f_doctor, other_scores_f_doctor]
m_doctor_scores = [positive_scores_m_doctor_com, negative_scores_m_doctor_com, neutral_scores_m_doctor_com, other_scores_m_doctor_com]

pt_f_doctor_scores = [positive_scores_f_doctor_pt, negative_scores_f_doctor_pt, neutral_scores_f_doctor_pt, other_scores_f_doctor_pt]
pt_m_doctor_scores = [positive_scores_m_doctor_pt_com, negative_scores_m_doctor_pt_com, neutral_scores_m_doctor_pt_com, other_scores_m_doctor_pt_com]

m_pilates_scores = [positive_scores_m_pilates, negative_scores_m_pilates, neutral_scores_m_pilates, other_scores_m_pilates]
f_pilates_scores = [positive_scores_f_pilates_com, negative_scores_f_pilates_com, neutral_scores_f_pilates_com, other_scores_f_pilates_com]

pt_m_pilates_scores = [positive_scores_m_pilates_pt, negative_scores_m_pilates_pt, neutral_scores_m_pilates_pt, other_scores_m_pilates_pt]
pt_f_pilates_scores = [positive_scores_f_pilates_pt_com, negative_scores_f_pilates_pt_com, neutral_scores_f_pilates_pt_com, other_scores_f_pilates_pt_com]

bar_width = 0.15
categories = ['Positive', 'Negative', 'Neutral', 'Other']
index = np.arange(len(categories))  # Reduce length by 1 for combined category

# Create the first subplot with original x-axis labels
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))  # Set the figsize parameter to your desired size

# Create the 4 subplot with original x-axis labels (baseline)
axs[0,0].bar(index, pt_m_nurse_scores, bar_width, label='Male Nurse')
axs[0,0].bar(index + bar_width, pt_f_nurse_scores, bar_width, label='Female Nurse')

axs[0,0].set_xlabel('Categories')
axs[0,0].set_ylabel('Scores')
axs[0,0].set_title('Regard Scores Comparison(PT)')
axs[0,0].set_xticks(index + bar_width/2)
axs[0,0].set_xticklabels(categories)
axs[0,0].legend()
axs[0,0].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(pt_m_nurse_scores):
    axs[0,0].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(pt_f_nurse_scores):
    axs[0,0].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

# Create the forth subplot with modified x-axis labels
axs[0,1].bar(index, pt_f_engineer_scores, bar_width, label='Female Engineer')
axs[0,1].bar(index + bar_width, pt_m_engineer_scores, bar_width, label='Male Engineer')

axs[0,1].set_xlabel('Categories')
axs[0,1].set_ylabel('Scores')
axs[0,1].set_title('Regard Scores Comparison(PT)')
axs[0,1].set_xticks(index + bar_width/2)
axs[0,1].set_xticklabels(categories)
axs[0,1].legend()
axs[0,1].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(pt_f_engineer_scores):
    axs[0,1].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(pt_m_engineer_scores):
    axs[0,1].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

# Create the forth subplot with modified x-axis labels
axs[0,2].bar(index, pt_f_doctor_scores, bar_width, label='Female Doctor')
axs[0,2].bar(index + bar_width, pt_m_doctor_scores, bar_width, label='Male Doctor')
axs[0,2].set_xlabel('Categories')
axs[0,2].set_ylabel('Scores')
axs[0,2].set_title('Regard Scores Comparison(PT)')
axs[0,2].set_xticks(index + bar_width/2)
axs[0,2].set_xticklabels(categories)
axs[0,2].legend()
axs[0,2].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(pt_f_doctor_scores):
    axs[0,2].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(pt_m_doctor_scores):
    axs[0,2].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

# Create the 4 subplot with original x-axis labels (baseline)
axs[0,3].bar(index, pt_m_pilates_scores, bar_width, label='Male Pilates')
axs[0,3].bar(index + bar_width, pt_f_pilates_scores, bar_width, label='Female Pilates')

axs[0,3].set_xlabel('Categories')
axs[0,3].set_ylabel('Scores')
axs[0,3].set_title('Regard Scores Comparison(PT)')
axs[0,3].set_xticks(index + bar_width/2)
axs[0,3].set_xticklabels(categories)
axs[0,3].legend()
axs[0,3].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(pt_m_pilates_scores):
    axs[0,3].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(pt_f_pilates_scores):
    axs[0,3].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

axs[1,0].bar(index, m_nurse_scores, bar_width, label='Male Nurse')
axs[1,0].bar(index + bar_width, f_nurse_scores, bar_width, label='Female Nurse')

axs[1,0].set_xlabel('Categories')
axs[1,0].set_ylabel('Scores')
axs[1,0].set_title('Regard Scores Comparison(FT)')
axs[1,0].set_xticks(index + bar_width/2)
axs[1,0].set_xticklabels(categories)
axs[1,0].legend()
axs[1,0].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(m_nurse_scores):
    axs[1,0].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(f_nurse_scores):
    axs[1,0].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

    # Create the second subplot with modified x-axis labels
axs[1,1].bar(index, f_engineer_scores, bar_width, label='Female Engineere')
axs[1,1].bar(index + bar_width, m_engineer_scores, bar_width, label='Male Engineer')
axs[1,1].set_xlabel('Categories')
axs[1,1].set_ylabel('Scores')
axs[1,1].set_title('Regard Scores Comparison(FT)')
axs[1,1].set_xticks(index + bar_width/2)
axs[1,1].set_xticklabels(categories)
axs[1,1].legend()
axs[1,1].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(f_engineer_scores):
    axs[1,1].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(m_engineer_scores):
    axs[1,1].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

# Create the third subplot with modified x-axis labels
axs[1,2].bar(index, f_doctor_scores, bar_width, label='Female Doctor')
axs[1,2].bar(index + bar_width, m_doctor_scores, bar_width, label='Male Doctor')

axs[1,2].set_xlabel('Categories')
axs[1,2].set_ylabel('Scores')
axs[1,2].set_title('Regard Scores Comparison(FT)')
axs[1,2].set_xticks(index + bar_width/2)
axs[1,2].set_xticklabels(categories)
axs[1,2].legend()
axs[1,2].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(f_doctor_scores):
    axs[1,2].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(m_doctor_scores):
    axs[1,2].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)

axs[1,3].bar(index, m_pilates_scores, bar_width, label='Male Pilates')
axs[1,3].bar(index + bar_width, f_pilates_scores, bar_width, label='Female Pilates')

axs[1,3].set_xlabel('Categories')
axs[1,3].set_ylabel('Scores')
axs[1,3].set_title('Regard Scores Comparison(FT)')
axs[1,3].set_xticks(index + bar_width/2)
axs[1,3].set_xticklabels(categories)
axs[1,3].legend()
axs[1,3].set_ylim(0, 1)
# Add specific values to each bar in the first subplot
for i, score in enumerate(m_pilates_scores):
    axs[1,3].text(i, score + 0.01, f'{score:.3f}', ha='right', va='bottom', fontsize=8)
for i, score in enumerate(f_pilates_scores):
    axs[1,3].text(i + bar_width, score + 0.01, f'{score:.3f}', ha='left', va='bottom', fontsize=8)


fig.suptitle('Comparison of Average Regard Scores with 80 nurse, engineer, doctor and pilates teacher prompts')
plt.tight_layout()
plt.savefig('image/regard_4level_bar_same_career/career.png')
plt.show()
# Out:
# 0.8022633221000433

# %% [markdown]
# ### doctor

# %%
df_reg_d = pd.read_csv('csv/nurse_doctor_regard_average_score.csv')
df_reg_d_comparison = pd.read_csv('csv/nurse_doctor_regard_average_score_comparison.csv')

# %%
f_doctor_score1 = df_reg_d['ft_f_doctor_score']
pt_f_doctor_score1 = df_reg_d['pt_f_doctor_score']

m_doctor_score1_com = df_reg_d_comparison['ft_m_doctor_score']
pt_m_doctor_score1_com = df_reg_d_comparison['pt_m_doctor_score']

# %%
# fine tuned
f_doctor_scores = ast.literal_eval(f_doctor_score1[0])
m_doctor_scores = ast.literal_eval(m_doctor_score1_com[0])

negative_scores_f_doctor = f_doctor_scores['negative']
neutral_scores_f_doctor = f_doctor_scores['neutral']
positive_scores_f_doctor = f_doctor_scores['positive']
other_scores_f_doctor = f_doctor_scores['other']

negative_scores_m_doctor_com = m_doctor_scores['negative']
neutral_scores_m_doctor_com = m_doctor_scores['neutral']
positive_scores_m_doctor_com = m_doctor_scores['positive']
other_scores_m_doctor_com = m_doctor_scores['other']

# baseline
pt_f_doctor_scores = ast.literal_eval(pt_f_doctor_score1[0])
pt_m_doctor_scores = ast.literal_eval(pt_m_doctor_score1_com[0])

negative_scores_f_doctor_pt = pt_f_doctor_scores['negative']
neutral_scores_f_doctor_pt = pt_f_doctor_scores['neutral']
positive_scores_f_doctor_pt = pt_f_doctor_scores['positive']
other_scores_f_doctor_pt = pt_f_doctor_scores['other']

negative_scores_m_doctor_pt_com = pt_m_doctor_scores['negative']
neutral_scores_m_doctor_pt_com = pt_m_doctor_scores['neutral']
positive_scores_m_doctor_pt_com = pt_m_doctor_scores['positive']
other_scores_m_doctor_pt_com = pt_m_doctor_scores['other']

# %%
f_doctor_scores = [positive_scores_f_doctor, negative_scores_f_doctor, neutral_scores_f_doctor, other_scores_f_doctor]
m_doctor_scores = [positive_scores_m_doctor_com, negative_scores_m_doctor_com, neutral_scores_m_doctor_com, other_scores_m_doctor_com]

pt_f_doctor_scores = [positive_scores_f_doctor_pt, negative_scores_f_doctor_pt, neutral_scores_f_doctor_pt, other_scores_f_doctor_pt]
pt_m_doctor_scores = [positive_scores_m_doctor_pt_com, negative_scores_m_doctor_pt_com, neutral_scores_m_doctor_pt_com, other_scores_m_doctor_pt_com]
 
bar_width = 0.25
categories = ['Positive', 'Negative', 'Neutral', 'Other']
index = np.arange(len(categories))  # Reduce length by 1 for combined category

# Create the first subplot with original x-axis labels
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 5))  # Set the figsize parameter to your desired size

axs[0].bar(index, f_doctor_scores, bar_width, label='Female Doctor')
axs[0].bar(index + bar_width, m_doctor_scores, bar_width, label='Male Doctor')

axs[0].set_xlabel('Categories')
axs[0].set_ylabel('Scores')
axs[0].set_title('Regard Scores Comparison(fine tuned)')
axs[0].set_xticks(index + bar_width/2)
axs[0].set_xticklabels(categories)
axs[0].legend()

# Create the third subplot with original x-axis labels (baseline)
axs[1].bar(index, pt_f_doctor_scores, bar_width, label='Female Doctor')
axs[1].bar(index + bar_width, pt_m_doctor_scores, bar_width, label='Male Doctor')

axs[1].set_xlabel('Categories')
axs[1].set_ylabel('Scores')
axs[1].set_title('Regard Scores Comparison(baseline)(baseline)')
axs[1].set_xticks(index + bar_width/2)
axs[1].set_xticklabels(categories)
axs[1].legend()

fig.suptitle('Comparison of Average Regard Scores with 80 male nurse prompts and 80 female engineer prompts')
plt.tight_layout()
plt.savefig('image/regard_4level_bar/n_e.png') 
plt.show()

# %% [markdown]
# pilates teacher
